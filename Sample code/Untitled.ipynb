# %%
print("hello world")
# Out:
# hello world

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d6f700e50a15> in <module>
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(True)
# Out:
# True

# %%
2+7
# Out:
# 9

# %%
a = "hello"
b = True

# %%
str
# Out:
# str

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
myfile = open ("test.dat", 'w')
myfile.write(myfile, numIN)
myfile.write("\n")
myfile.write(myfile, "Helloworld")
myfile.close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-43fac062d3fa> in <module>
#       1 myfile = open ("test.dat", 'w')
# ----> 2 myfile.write(myfile, numIN)
#       3 myfile.write("\n")
#       4 myfile.write(myfile, "Helloworld")
#       5 myfile.close
#
# NameError: name 'numIN' is not defined
